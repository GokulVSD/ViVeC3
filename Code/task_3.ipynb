# %% [markdown]
#     Instructions:
#     1. Generate the vector database if not already generated.
#     2. Press Run All (or restart kernel and run all cells).
#     3. You will be prompted to provide input values.
#
#
#     Task 3: Implement a program which,
#     – given even-numbered Caltec101 images,
#     ∗ creates an m-NN classifer (for a user specified m),
#     ∗ creates a decision-tree classifier,
#     ∗ creates a PPR based classifier.
#     For this task, you can use feature space of your choice.
#     – for the odd numbered images, predicts the most likely labels using the user selected classifier.
#     The system should also output per-label precision, recall, and F1-score values as well as output an overall accuracy
#     value.

# %%
FEATURE_SPACE = input("Provide a feature space [color, hog, avgpool, layer3, fc, resnet].")

CLASSIFIER_TYPE = input("Provide the type of classifier you want to use [knn, ppn, decision_tree]")

# %%
def filter_data(feature_vectors, image_ids):
    filtered_data = {}
    for i in feature_vectors:
        feature_vector = feature_vectors[i]
        if i in image_ids:
            filtered_data[i] = feature_vector
        if len(filtered_data) == len(image_ids):
            break
    return filtered_data

# %%
from utils.database_utils import retrieve, store, exists
train_data = retrieve(f'{FEATURE_SPACE}.pt')
test_data = retrieve(f'odd{FEATURE_SPACE}.pt')

# %%
if CLASSIFIER_TYPE == "knn":
    from classifiers.knn import KNNClassifier
    K = int(input("Provide a value for k to use in the k-NN classifier"))
    classifier = KNNClassifier(K, train_data)
    out_statement = "k-NN Classifier for k = " + str(K)

elif CLASSIFIER_TYPE == "ppn":
    N = 5
    M = 4
    damping_factor = float(input("Provide a value for PPR Random Jump Probability"))
    from classifiers.ppn import PPNClassifier
    classifier = PPNClassifier(N, M, train_data, feature_space=FEATURE_SPACE, damping_factor=damping_factor)
    out_statement = "Personalized Page Rank Classifier with M = {}, N = {}, and Random Jump Probability = {}".format(M, N, damping_factor)

elif CLASSIFIER_TYPE == 'decision_tree':
    if exists(f'{FEATURE_SPACE}_decision_tree_classifier.pt'):
        classifier = retrieve(f'{FEATURE_SPACE}_decision_tree_classifier.pt')
        IG_MODE = classifier.mode
        MIN_SAMPLE = classifier.mimimum_samples_leaf
        MAX_DEPTH = 0 if classifier.max_depth == float('inf') else classifier.max_depth
    else:
        print("Training Decision Tree Classifier for ", FEATURE_SPACE)
        from classifiers.decision_tree import DecisionTreeClassifier
        IG_MODE = input("Provide information gain measurement mode - gini or entropy")
        MIN_SAMPLE = int(input("Provide minimum sample size for a node to split"))
        MAX_DEPTH = int(input("Provide maximum depth of the tree. For unbounded depth enter 0"))
        classifier = DecisionTreeClassifier(mode=IG_MODE, mimimum_samples_leaf=MIN_SAMPLE, max_depth=MAX_DEPTH)
        classifier.fit(train_data)
        store(classifier, f'{FEATURE_SPACE}_decision_tree_classifier.pt')
    out_statement = f"Decision Tree Classifier with Mode = {IG_MODE}, Min-Sample-Size= {MIN_SAMPLE}, and Max-Depth = {MAX_DEPTH}"


print("Running Predictions for " + out_statement)
# Cached results retrieval, or run again.
if CLASSIFIER_TYPE == "ppn" and exists(f'{FEATURE_SPACE}_ppn_predictions.pt'):
    output_labels = retrieve(f'{FEATURE_SPACE}_ppn_predictions.pt')
    print(output_labels)
    for opl in output_labels:
        print(f"IMG_ID: {opl['img_id']}\tTrue label: {opl['test_label']}\tPred labels: {opl['predicted_label']}")
else:
    output_labels = classifier.classify(test_data)
    if CLASSIFIER_TYPE == "ppn":
        store(output_labels, f'{FEATURE_SPACE}_ppn_predictions.pt')
# Out:
# Running Predictions for Decision Tree Classifier with Mode = gini, Min-Sample-Size= 25, and Max-Depth = 0
# IMG_ID: 1	True label: Faces	Pred label: Faces
# IMG_ID: 3	True label: Faces	Pred label: Faces_easy
# IMG_ID: 5	True label: Faces	Pred label: Faces
# IMG_ID: 7	True label: Faces	Pred label: Faces
# IMG_ID: 9	True label: Faces	Pred label: Faces
# IMG_ID: 11	True label: Faces	Pred label: Faces
# IMG_ID: 13	True label: Faces	Pred label: Faces_easy
# IMG_ID: 15	True label: Faces	Pred label: Faces
# IMG_ID: 17	True label: Faces	Pred label: Faces
# IMG_ID: 19	True label: Faces	Pred label: Faces
# IMG_ID: 21	True label: Faces	Pred label: Faces
# IMG_ID: 23	True label: Faces	Pred label: Faces
# IMG_ID: 25	True label: Faces	Pred label: Faces
# IMG_ID: 27	True label: Faces	Pred label: Faces
# IMG_ID: 29	True label: Faces	Pred label: Faces
# IMG_ID: 31	True label: Faces	Pred label: Faces
# IMG_ID: 33	True label: Faces	Pred label: Faces
# IMG_ID: 35	True label: Faces	Pred label: Faces
# IMG_ID: 37	True label: Faces	Pred label: Faces_easy
# IMG_ID: 39	True label: Faces	Pred label: Faces
# IMG_ID: 41	True label: Faces	Pred label: Faces
# IMG_ID: 43	True label: Faces	Pred label: Faces_easy
# IMG_ID: 45	True label: Faces	Pred label: Faces
# IMG_ID: 47	True label: Faces	Pred label: Faces
# IMG_ID: 49	True label: Faces	Pred label: Faces
# IMG_ID: 51	True label: Faces	Pred label: Faces
# IMG_ID: 53	True label: Faces	Pred label: Faces
# IMG_ID: 55	True label: Faces	Pred label: Faces
# IMG_ID: 57	True label: Faces	Pred label: Faces
# IMG_ID: 59	True label: Faces	Pred label: Faces
# IMG_ID: 61	True label: Faces	Pred label: Faces
# IMG_ID: 63	True label: Faces	Pred label: Faces
# IMG_ID: 65	True label: Faces	Pred label: Faces
# IMG_ID: 67	True label: Faces	Pred label: Faces
# IMG_ID: 69	True label: Faces	Pred label: Faces
# IMG_ID: 71	True label: Faces	Pred label: Faces
# IMG_ID: 73	True label: Faces	Pred label: Faces
# IMG_ID: 75	True label: Faces	Pred label: Faces
# IMG_ID: 77	True label: Faces	Pred label: Faces
# IMG_ID: 79	True label: Faces	Pred label: Faces
# IMG_ID: 81	True label: Faces	Pred label: Faces
# IMG_ID: 83	True label: Faces	Pred label: Faces
# IMG_ID: 85	True label: Faces	Pred label: Faces
# IMG_ID: 87	True label: Faces	Pred label: Faces
# IMG_ID: 89	True label: Faces	Pred label: Faces_easy
# IMG_ID: 91	True label: Faces	Pred label: Faces
# IMG_ID: 93	True label: Faces	Pred label: Faces
# IMG_ID: 95	True label: Faces	Pred label: Faces
# IMG_ID: 97	True label: Faces	Pred label: Faces
# IMG_ID: 99	True label: Faces	Pred label: Faces
# IMG_ID: 101	True label: Faces	Pred label: Faces_easy
# IMG_ID: 103	True label: Faces	Pred label: Faces
# IMG_ID: 105	True label: Faces	Pred label: Faces
# IMG_ID: 107	True label: Faces	Pred label: wheelchair
# IMG_ID: 109	True label: Faces	Pred label: Faces_easy
# IMG_ID: 111	True label: Faces	Pred label: Faces
# IMG_ID: 113	True label: Faces	Pred label: Faces
# IMG_ID: 115	True label: Faces	Pred label: Faces
# IMG_ID: 117	True label: Faces	Pred label: Faces
# IMG_ID: 119	True label: Faces	Pred label: Faces
# IMG_ID: 121	True label: Faces	Pred label: Faces
# IMG_ID: 123	True label: Faces	Pred label: Faces
# IMG_ID: 125	True label: Faces	Pred label: Faces
# IMG_ID: 127	True label: Faces	Pred label: Faces
# IMG_ID: 129	True label: Faces	Pred label: Faces
# IMG_ID: 131	True label: Faces	Pred label: Faces
# IMG_ID: 133	True label: Faces	Pred label: Faces
# IMG_ID: 135	True label: Faces	Pred label: Faces
# IMG_ID: 137	True label: Faces	Pred label: Faces
# IMG_ID: 139	True label: Faces	Pred label: Faces
# IMG_ID: 141	True label: Faces	Pred label: Faces
# IMG_ID: 143	True label: Faces	Pred label: Faces
# IMG_ID: 145	True label: Faces	Pred label: Faces
# IMG_ID: 147	True label: Faces	Pred label: Faces
# IMG_ID: 149	True label: Faces	Pred label: Faces
# IMG_ID: 151	True label: Faces	Pred label: Faces
# IMG_ID: 153	True label: Faces	Pred label: Faces
# IMG_ID: 155	True label: Faces	Pred label: Faces_easy
# IMG_ID: 157	True label: Faces	Pred label: Faces
# IMG_ID: 159	True label: Faces	Pred label: Faces
# IMG_ID: 161	True label: Faces	Pred label: Faces_easy
# IMG_ID: 163	True label: Faces	Pred label: Faces_easy
# IMG_ID: 165	True label: Faces	Pred label: Faces
# IMG_ID: 167	True label: Faces	Pred label: Faces
# IMG_ID: 169	True label: Faces	Pred label: Faces
# IMG_ID: 171	True label: Faces	Pred label: Faces
# IMG_ID: 173	True label: Faces	Pred label: Faces
# IMG_ID: 175	True label: Faces	Pred label: Faces_easy
# IMG_ID: 177	True label: Faces	Pred label: Faces
# IMG_ID: 179	True label: Faces	Pred label: Faces_easy
# IMG_ID: 181	True label: Faces	Pred label: Faces
# IMG_ID: 183	True label: Faces	Pred label: Faces_easy
# IMG_ID: 185	True label: Faces	Pred label: Faces_easy
# IMG_ID: 187	True label: Faces	Pred label: Faces
# IMG_ID: 189	True label: Faces	Pred label: Faces
# IMG_ID: 191	True label: Faces	Pred label: Faces
# IMG_ID: 193	True label: Faces	Pred label: Faces
# IMG_ID: 195	True label: Faces	Pred label: Faces
# IMG_ID: 197	True label: Faces	Pred label: Faces
# IMG_ID: 199	True label: Faces	Pred label: Faces
# IMG_ID: 201	True label: Faces	Pred label: Faces
# IMG_ID: 203	True label: Faces	Pred label: Faces
# IMG_ID: 205	True label: Faces	Pred label: Faces_easy
# IMG_ID: 207	True label: Faces	Pred label: Faces
# IMG_ID: 209	True label: Faces	Pred label: Faces
# IMG_ID: 211	True label: Faces	Pred label: Faces_easy
# IMG_ID: 213	True label: Faces	Pred label: Faces
# IMG_ID: 215	True label: Faces	Pred label: Faces
# IMG_ID: 217	True label: Faces	Pred label: Faces
# IMG_ID: 219	True label: Faces	Pred label: Faces_easy
# IMG_ID: 221	True label: Faces	Pred label: Faces
# IMG_ID: 223	True label: Faces	Pred label: Faces
# IMG_ID: 225	True label: Faces	Pred label: Faces
# IMG_ID: 227	True label: Faces	Pred label: Faces
# IMG_ID: 229	True label: Faces	Pred label: Faces
# IMG_ID: 231	True label: Faces	Pred label: Faces_easy
# IMG_ID: 233	True label: Faces	Pred label: Faces
# IMG_ID: 235	True label: Faces	Pred label: Faces
# IMG_ID: 237	True label: Faces	Pred label: Faces
# IMG_ID: 239	True label: Faces	Pred label: Faces
# IMG_ID: 241	True label: Faces	Pred label: Faces_easy
# IMG_ID: 243	True label: Faces	Pred label: Faces
# IMG_ID: 245	True label: Faces	Pred label: Faces
# IMG_ID: 247	True label: Faces	Pred label: Faces
# IMG_ID: 249	True label: Faces	Pred label: Faces
# IMG_ID: 251	True label: Faces	Pred label: Faces
# IMG_ID: 253	True label: Faces	Pred label: Faces
# IMG_ID: 255	True label: Faces	Pred label: Faces
# IMG_ID: 257	True label: Faces	Pred label: Faces_easy
# IMG_ID: 259	True label: Faces	Pred label: Faces_easy
# IMG_ID: 261	True label: Faces	Pred label: Faces
# IMG_ID: 263	True label: Faces	Pred label: Faces_easy
# IMG_ID: 265	True label: Faces	Pred label: Faces
# IMG_ID: 267	True label: Faces	Pred label: Faces
# IMG_ID: 269	True label: Faces	Pred label: Faces
# IMG_ID: 271	True label: Faces	Pred label: Faces
# IMG_ID: 273	True label: Faces	Pred label: Faces
# IMG_ID: 275	True label: Faces	Pred label: Faces
# IMG_ID: 277	True label: Faces	Pred label: Faces
# IMG_ID: 279	True label: Faces	Pred label: Faces
# IMG_ID: 281	True label: Faces	Pred label: Faces
# IMG_ID: 283	True label: Faces	Pred label: Faces
# IMG_ID: 285	True label: Faces	Pred label: Faces_easy
# IMG_ID: 287	True label: Faces	Pred label: Faces_easy
# IMG_ID: 289	True label: Faces	Pred label: Faces_easy
# IMG_ID: 291	True label: Faces	Pred label: Faces_easy
# IMG_ID: 293	True label: Faces	Pred label: Faces_easy
# IMG_ID: 295	True label: Faces	Pred label: Faces
# IMG_ID: 297	True label: Faces	Pred label: Faces_easy
# IMG_ID: 299	True label: Faces	Pred label: Faces
# IMG_ID: 301	True label: Faces	Pred label: Faces
# IMG_ID: 303	True label: Faces	Pred label: Faces_easy
# IMG_ID: 305	True label: Faces	Pred label: Faces_easy
# IMG_ID: 307	True label: Faces	Pred label: Faces
# IMG_ID: 309	True label: Faces	Pred label: Faces
# IMG_ID: 311	True label: Faces	Pred label: Faces
# IMG_ID: 313	True label: Faces	Pred label: pyramid
# IMG_ID: 315	True label: Faces	Pred label: Faces
# IMG_ID: 317	True label: Faces	Pred label: Faces
# IMG_ID: 319	True label: Faces	Pred label: Faces_easy
# IMG_ID: 321	True label: Faces	Pred label: Faces_easy
# IMG_ID: 323	True label: Faces	Pred label: Faces_easy
# IMG_ID: 325	True label: Faces	Pred label: Faces_easy
# IMG_ID: 327	True label: Faces	Pred label: Faces
# IMG_ID: 329	True label: Faces	Pred label: Faces
# IMG_ID: 331	True label: Faces	Pred label: Faces
# IMG_ID: 333	True label: Faces	Pred label: Faces_easy
# IMG_ID: 335	True label: Faces	Pred label: Faces
# IMG_ID: 337	True label: Faces	Pred label: Faces
# IMG_ID: 339	True label: Faces	Pred label: Faces
# IMG_ID: 341	True label: Faces	Pred label: Faces_easy
# IMG_ID: 343	True label: Faces	Pred label: Faces
# IMG_ID: 345	True label: Faces	Pred label: Faces
# IMG_ID: 347	True label: Faces	Pred label: Faces_easy
# IMG_ID: 349	True label: Faces	Pred label: Faces
# IMG_ID: 351	True label: Faces	Pred label: Faces
# IMG_ID: 353	True label: Faces	Pred label: Faces
# IMG_ID: 355	True label: Faces	Pred label: Faces
# IMG_ID: 357	True label: Faces	Pred label: Faces
# IMG_ID: 359	True label: Faces	Pred label: Faces
# IMG_ID: 361	True label: Faces	Pred label: Faces
# IMG_ID: 363	True label: Faces	Pred label: Faces
# IMG_ID: 365	True label: Faces	Pred label: Faces_easy
# IMG_ID: 367	True label: Faces	Pred label: Faces
# IMG_ID: 369	True label: Faces	Pred label: Faces
# IMG_ID: 371	True label: Faces	Pred label: Faces
# IMG_ID: 373	True label: Faces	Pred label: Faces
# IMG_ID: 375	True label: Faces	Pred label: Faces
# IMG_ID: 377	True label: Faces	Pred label: wheelchair
# IMG_ID: 379	True label: Faces	Pred label: Faces
# IMG_ID: 381	True label: Faces	Pred label: Faces
# IMG_ID: 383	True label: Faces	Pred label: wheelchair
# IMG_ID: 385	True label: Faces	Pred label: Faces
# IMG_ID: 387	True label: Faces	Pred label: Faces
# IMG_ID: 389	True label: Faces	Pred label: Faces_easy
# IMG_ID: 391	True label: Faces	Pred label: Faces
# IMG_ID: 393	True label: Faces	Pred label: Faces
# IMG_ID: 395	True label: Faces	Pred label: Faces
# IMG_ID: 397	True label: Faces	Pred label: Faces
# IMG_ID: 399	True label: Faces	Pred label: Faces
# IMG_ID: 401	True label: Faces	Pred label: Faces_easy
# IMG_ID: 403	True label: Faces	Pred label: Faces
# IMG_ID: 405	True label: Faces	Pred label: Faces
# IMG_ID: 407	True label: Faces	Pred label: Faces
# IMG_ID: 409	True label: Faces	Pred label: Faces
# IMG_ID: 411	True label: Faces	Pred label: Faces
# IMG_ID: 413	True label: Faces	Pred label: Faces
# IMG_ID: 415	True label: Faces	Pred label: Faces
# IMG_ID: 417	True label: Faces	Pred label: Faces
# IMG_ID: 419	True label: Faces	Pred label: Faces
# IMG_ID: 421	True label: Faces	Pred label: Faces
# IMG_ID: 423	True label: Faces	Pred label: Faces
# IMG_ID: 425	True label: Faces	Pred label: Faces
# IMG_ID: 427	True label: Faces	Pred label: Faces
# IMG_ID: 429	True label: Faces	Pred label: Faces
# IMG_ID: 431	True label: Faces	Pred label: Faces
# IMG_ID: 433	True label: Faces	Pred label: Faces
# IMG_ID: 435	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 437	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 439	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 441	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 443	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 445	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 447	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 449	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 451	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 453	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 455	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 457	True label: Faces_easy	Pred label: Faces
# IMG_ID: 459	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 461	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 463	True label: Faces_easy	Pred label: Faces
# IMG_ID: 465	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 467	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 469	True label: Faces_easy	Pred label: Faces
# IMG_ID: 471	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 473	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 475	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 477	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 479	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 481	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 483	True label: Faces_easy	Pred label: Faces
# IMG_ID: 485	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 487	True label: Faces_easy	Pred label: Faces
# IMG_ID: 489	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 491	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 493	True label: Faces_easy	Pred label: Faces
# IMG_ID: 495	True label: Faces_easy	Pred label: Faces
# IMG_ID: 497	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 499	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 501	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 503	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 505	True label: Faces_easy	Pred label: Faces
# IMG_ID: 507	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 509	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 511	True label: Faces_easy	Pred label: Faces
# IMG_ID: 513	True label: Faces_easy	Pred label: Faces
# IMG_ID: 515	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 517	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 519	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 521	True label: Faces_easy	Pred label: Faces
# IMG_ID: 523	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 525	True label: Faces_easy	Pred label: Faces
# IMG_ID: 527	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 529	True label: Faces_easy	Pred label: Faces
# IMG_ID: 531	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 533	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 535	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 537	True label: Faces_easy	Pred label: Faces
# IMG_ID: 539	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 541	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 543	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 545	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 547	True label: Faces_easy	Pred label: Faces
# IMG_ID: 549	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 551	True label: Faces_easy	Pred label: Faces
# IMG_ID: 553	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 555	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 557	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 559	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 561	True label: Faces_easy	Pred label: Faces
# IMG_ID: 563	True label: Faces_easy	Pred label: Faces
# IMG_ID: 565	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 567	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 569	True label: Faces_easy	Pred label: Faces
# IMG_ID: 571	True label: Faces_easy	Pred label: Faces
# IMG_ID: 573	True label: Faces_easy	Pred label: Faces
# IMG_ID: 575	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 577	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 579	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 581	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 583	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 585	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 587	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 589	True label: Faces_easy	Pred label: Faces
# IMG_ID: 591	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 593	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 595	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 597	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 599	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 601	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 603	True label: Faces_easy	Pred label: panda
# IMG_ID: 605	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 607	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 609	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 611	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 613	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 615	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 617	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 619	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 621	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 623	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 625	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 627	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 629	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 631	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 633	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 635	True label: Faces_easy	Pred label: Faces
# IMG_ID: 637	True label: Faces_easy	Pred label: Faces
# IMG_ID: 639	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 641	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 643	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 645	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 647	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 649	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 651	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 653	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 655	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 657	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 659	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 661	True label: Faces_easy	Pred label: Faces
# IMG_ID: 663	True label: Faces_easy	Pred label: Faces
# IMG_ID: 665	True label: Faces_easy	Pred label: wheelchair
# IMG_ID: 667	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 669	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 671	True label: Faces_easy	Pred label: Faces
# IMG_ID: 673	True label: Faces_easy	Pred label: Faces
# IMG_ID: 675	True label: Faces_easy	Pred label: Faces
# IMG_ID: 677	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 679	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 681	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 683	True label: Faces_easy	Pred label: Faces
# IMG_ID: 685	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 687	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 689	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 691	True label: Faces_easy	Pred label: Faces
# IMG_ID: 693	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 695	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 697	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 699	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 701	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 703	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 705	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 707	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 709	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 711	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 713	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 715	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 717	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 719	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 721	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 723	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 725	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 727	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 729	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 731	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 733	True label: Faces_easy	Pred label: Faces
# IMG_ID: 735	True label: Faces_easy	Pred label: Faces
# IMG_ID: 737	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 739	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 741	True label: Faces_easy	Pred label: Faces
# IMG_ID: 743	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 745	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 747	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 749	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 751	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 753	True label: Faces_easy	Pred label: Faces
# IMG_ID: 755	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 757	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 759	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 761	True label: Faces_easy	Pred label: Faces
# IMG_ID: 763	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 765	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 767	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 769	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 771	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 773	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 775	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 777	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 779	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 781	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 783	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 785	True label: Faces_easy	Pred label: Faces
# IMG_ID: 787	True label: Faces_easy	Pred label: Faces
# IMG_ID: 789	True label: Faces_easy	Pred label: Faces
# IMG_ID: 791	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 793	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 795	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 797	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 799	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 801	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 803	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 805	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 807	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 809	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 811	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 813	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 815	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 817	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 819	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 821	True label: Faces_easy	Pred label: Faces
# IMG_ID: 823	True label: Faces_easy	Pred label: Faces
# IMG_ID: 825	True label: Faces_easy	Pred label: beaver
# IMG_ID: 827	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 829	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 831	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 833	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 835	True label: Faces_easy	Pred label: Faces
# IMG_ID: 837	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 839	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 841	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 843	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 845	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 847	True label: Faces_easy	Pred label: Faces
# IMG_ID: 849	True label: Faces_easy	Pred label: Faces
# IMG_ID: 851	True label: Faces_easy	Pred label: Faces
# IMG_ID: 853	True label: Faces_easy	Pred label: Faces
# IMG_ID: 855	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 857	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 859	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 861	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 863	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 865	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 867	True label: Faces_easy	Pred label: Faces_easy
# IMG_ID: 869	True label: Faces_easy	Pred label: Faces
# IMG_ID: 871	True label: Leopards	Pred label: Leopards
# IMG_ID: 873	True label: Leopards	Pred label: Leopards
# IMG_ID: 875	True label: Leopards	Pred label: Leopards
# IMG_ID: 877	True label: Leopards	Pred label: Leopards
# IMG_ID: 879	True label: Leopards	Pred label: Leopards
# IMG_ID: 881	True label: Leopards	Pred label: Leopards
# IMG_ID: 883	True label: Leopards	Pred label: Leopards
# IMG_ID: 885	True label: Leopards	Pred label: wild_cat
# IMG_ID: 887	True label: Leopards	Pred label: Leopards
# IMG_ID: 889	True label: Leopards	Pred label: Leopards
# IMG_ID: 891	True label: Leopards	Pred label: Leopards
# IMG_ID: 893	True label: Leopards	Pred label: Leopards
# IMG_ID: 895	True label: Leopards	Pred label: Leopards
# IMG_ID: 897	True label: Leopards	Pred label: Leopards
# IMG_ID: 899	True label: Leopards	Pred label: Leopards
# IMG_ID: 901	True label: Leopards	Pred label: wild_cat
# IMG_ID: 903	True label: Leopards	Pred label: Leopards
# IMG_ID: 905	True label: Leopards	Pred label: Leopards
# IMG_ID: 907	True label: Leopards	Pred label: Leopards
# IMG_ID: 909	True label: Leopards	Pred label: Leopards
# IMG_ID: 911	True label: Leopards	Pred label: Leopards
# IMG_ID: 913	True label: Leopards	Pred label: Leopards
# IMG_ID: 915	True label: Leopards	Pred label: Leopards
# IMG_ID: 917	True label: Leopards	Pred label: Leopards
# IMG_ID: 919	True label: Leopards	Pred label: Leopards
# IMG_ID: 921	True label: Leopards	Pred label: Leopards
# IMG_ID: 923	True label: Leopards	Pred label: Leopards
# IMG_ID: 925	True label: Leopards	Pred label: Leopards
# IMG_ID: 927	True label: Leopards	Pred label: Leopards
# IMG_ID: 929	True label: Leopards	Pred label: Leopards
# IMG_ID: 931	True label: Leopards	Pred label: Leopards
# IMG_ID: 933	True label: Leopards	Pred label: Leopards
# IMG_ID: 935	True label: Leopards	Pred label: Leopards
# IMG_ID: 937	True label: Leopards	Pred label: Leopards
# IMG_ID: 939	True label: Leopards	Pred label: Leopards
# IMG_ID: 941	True label: Leopards	Pred label: Leopards
# IMG_ID: 943	True label: Leopards	Pred label: Leopards
# IMG_ID: 945	True label: Leopards	Pred label: Leopards
# IMG_ID: 947	True label: Leopards	Pred label: Leopards
# IMG_ID: 949	True label: Leopards	Pred label: Leopards
# IMG_ID: 951	True label: Leopards	Pred label: Leopards
# IMG_ID: 953	True label: Leopards	Pred label: Leopards
# IMG_ID: 955	True label: Leopards	Pred label: Leopards
# IMG_ID: 957	True label: Leopards	Pred label: Leopards
# IMG_ID: 959	True label: Leopards	Pred label: Leopards
# IMG_ID: 961	True label: Leopards	Pred label: Leopards
# IMG_ID: 963	True label: Leopards	Pred label: Leopards
# IMG_ID: 965	True label: Leopards	Pred label: Leopards
# IMG_ID: 967	True label: Leopards	Pred label: Leopards
# IMG_ID: 969	True label: Leopards	Pred label: Leopards
# IMG_ID: 971	True label: Leopards	Pred label: Leopards
# IMG_ID: 973	True label: Leopards	Pred label: Leopards
# IMG_ID: 975	True label: Leopards	Pred label: Leopards
# IMG_ID: 977	True label: Leopards	Pred label: Leopards
# IMG_ID: 979	True label: Leopards	Pred label: Leopards
# IMG_ID: 981	True label: Leopards	Pred label: Leopards
# IMG_ID: 983	True label: Leopards	Pred label: Leopards
# IMG_ID: 985	True label: Leopards	Pred label: Leopards
# IMG_ID: 987	True label: Leopards	Pred label: Leopards
# IMG_ID: 989	True label: Leopards	Pred label: Leopards
# IMG_ID: 991	True label: Leopards	Pred label: Leopards
# IMG_ID: 993	True label: Leopards	Pred label: Leopards
# IMG_ID: 995	True label: Leopards	Pred label: Leopards
# IMG_ID: 997	True label: Leopards	Pred label: Leopards
# IMG_ID: 999	True label: Leopards	Pred label: wild_cat
# IMG_ID: 1001	True label: Leopards	Pred label: wild_cat
# IMG_ID: 1003	True label: Leopards	Pred label: Leopards
# IMG_ID: 1005	True label: Leopards	Pred label: Leopards
# IMG_ID: 1007	True label: Leopards	Pred label: Leopards
# IMG_ID: 1009	True label: Leopards	Pred label: Leopards
# IMG_ID: 1011	True label: Leopards	Pred label: Leopards
# IMG_ID: 1013	True label: Leopards	Pred label: Leopards
# IMG_ID: 1015	True label: Leopards	Pred label: Leopards
# IMG_ID: 1017	True label: Leopards	Pred label: Leopards
# IMG_ID: 1019	True label: Leopards	Pred label: Leopards
# IMG_ID: 1021	True label: Leopards	Pred label: Leopards
# IMG_ID: 1023	True label: Leopards	Pred label: Leopards
# IMG_ID: 1025	True label: Leopards	Pred label: Leopards
# IMG_ID: 1027	True label: Leopards	Pred label: Leopards
# IMG_ID: 1029	True label: Leopards	Pred label: Leopards
# IMG_ID: 1031	True label: Leopards	Pred label: Leopards
# IMG_ID: 1033	True label: Leopards	Pred label: Leopards
# IMG_ID: 1035	True label: Leopards	Pred label: Leopards
# IMG_ID: 1037	True label: Leopards	Pred label: Leopards
# IMG_ID: 1039	True label: Leopards	Pred label: Leopards
# IMG_ID: 1041	True label: Leopards	Pred label: Leopards
# IMG_ID: 1043	True label: Leopards	Pred label: Leopards
# IMG_ID: 1045	True label: Leopards	Pred label: Leopards
# IMG_ID: 1047	True label: Leopards	Pred label: Leopards
# IMG_ID: 1049	True label: Leopards	Pred label: Leopards
# IMG_ID: 1051	True label: Leopards	Pred label: Leopards
# IMG_ID: 1053	True label: Leopards	Pred label: Leopards
# IMG_ID: 1055	True label: Leopards	Pred label: Leopards
# IMG_ID: 1057	True label: Leopards	Pred label: Leopards
# IMG_ID: 1059	True label: Leopards	Pred label: Leopards
# IMG_ID: 1061	True label: Leopards	Pred label: Leopards
# IMG_ID: 1063	True label: Leopards	Pred label: Leopards
# IMG_ID: 1065	True label: Leopards	Pred label: Leopards
# IMG_ID: 1067	True label: Leopards	Pred label: Leopards
# IMG_ID: 1069	True label: Leopards	Pred label: Leopards
# IMG_ID: 1071	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1073	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1075	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1077	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1079	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1081	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1083	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1085	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1087	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1089	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1091	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1093	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1095	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1097	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1099	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1101	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1103	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1105	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1107	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1109	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1111	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1113	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1115	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1117	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1119	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1121	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1123	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1125	True label: Motorbikes	Pred label: inline_skate
# IMG_ID: 1127	True label: Motorbikes	Pred label: inline_skate
# IMG_ID: 1129	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1131	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1133	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1135	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1137	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1139	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1141	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1143	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1145	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1147	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1149	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1151	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1153	True label: Motorbikes	Pred label: inline_skate
# IMG_ID: 1155	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1157	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1159	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1161	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1163	True label: Motorbikes	Pred label: wheelchair
# IMG_ID: 1165	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1167	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1169	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1171	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1173	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1175	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1177	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1179	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1181	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1183	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1185	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1187	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1189	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1191	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1193	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1195	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1197	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1199	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1201	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1203	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1205	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1207	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1209	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1211	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1213	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1215	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1217	True label: Motorbikes	Pred label: inline_skate
# IMG_ID: 1219	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1221	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1223	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1225	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1227	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1229	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1231	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1233	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1235	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1237	True label: Motorbikes	Pred label: wheelchair
# IMG_ID: 1239	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1241	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1243	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1245	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1247	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1249	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1251	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1253	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1255	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1257	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1259	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1261	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1263	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1265	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1267	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1269	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1271	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1273	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1275	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1277	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1279	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1281	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1283	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1285	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1287	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1289	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1291	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1293	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1295	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1297	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1299	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1301	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1303	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1305	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1307	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1309	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1311	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1313	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1315	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1317	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1319	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1321	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1323	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1325	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1327	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1329	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1331	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1333	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1335	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1337	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1339	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1341	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1343	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1345	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1347	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1349	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1351	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1353	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1355	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1357	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1359	True label: Motorbikes	Pred label: Faces
# IMG_ID: 1361	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1363	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1365	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1367	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1369	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1371	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1373	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1375	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1377	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1379	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1381	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1383	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1385	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1387	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1389	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1391	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1393	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1395	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1397	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1399	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1401	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1403	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1405	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1407	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1409	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1411	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1413	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1415	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1417	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1419	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1421	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1423	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1425	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1427	True label: Motorbikes	Pred label: mayfly
# IMG_ID: 1429	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1431	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1433	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1435	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1437	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1439	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1441	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1443	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1445	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1447	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1449	True label: Motorbikes	Pred label: helicopter
# IMG_ID: 1451	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1453	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1455	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1457	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1459	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1461	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1463	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1465	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1467	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1469	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1471	True label: Motorbikes	Pred label: helicopter
# IMG_ID: 1473	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1475	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1477	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1479	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1481	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1483	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1485	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1487	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1489	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1491	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1493	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1495	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1497	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1499	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1501	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1503	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1505	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1507	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1509	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1511	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1513	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1515	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1517	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1519	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1521	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1523	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1525	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1527	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1529	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1531	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1533	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1535	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1537	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1539	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1541	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1543	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1545	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1547	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1549	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1551	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1553	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1555	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1557	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1559	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1561	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1563	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1565	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1567	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1569	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1571	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1573	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1575	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1577	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1579	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1581	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1583	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1585	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1587	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1589	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1591	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1593	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1595	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1597	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1599	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1601	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1603	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1605	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1607	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1609	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1611	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1613	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1615	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1617	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1619	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1621	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1623	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1625	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1627	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1629	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1631	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1633	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1635	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1637	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1639	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1641	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1643	True label: Motorbikes	Pred label: wheelchair
# IMG_ID: 1645	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1647	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1649	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1651	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1653	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1655	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1657	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1659	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1661	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1663	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1665	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1667	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1669	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1671	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1673	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1675	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1677	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1679	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1681	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1683	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1685	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1687	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1689	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1691	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1693	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1695	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1697	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1699	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1701	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1703	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1705	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1707	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1709	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1711	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1713	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1715	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1717	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1719	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1721	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1723	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1725	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1727	True label: Motorbikes	Pred label: Motorbikes
# IMG_ID: 1729	True label: Motorbikes	Pred label: Motorbikes
# ...
# IMG_ID: 8081	True label: umbrella	Pred label: umbrella
# IMG_ID: 8083	True label: umbrella	Pred label: umbrella
# IMG_ID: 8085	True label: umbrella	Pred label: bonsai
# IMG_ID: 8087	True label: umbrella	Pred label: butterfly
# IMG_ID: 8089	True label: umbrella	Pred label: umbrella
# IMG_ID: 8091	True label: umbrella	Pred label: umbrella
# IMG_ID: 8093	True label: umbrella	Pred label: umbrella
# IMG_ID: 8095	True label: umbrella	Pred label: umbrella
# IMG_ID: 8097	True label: umbrella	Pred label: beaver
# IMG_ID: 8099	True label: umbrella	Pred label: umbrella
# IMG_ID: 8101	True label: umbrella	Pred label: umbrella
# IMG_ID: 8103	True label: umbrella	Pred label: umbrella
# IMG_ID: 8105	True label: umbrella	Pred label: umbrella
# IMG_ID: 8107	True label: umbrella	Pred label: umbrella
# IMG_ID: 8109	True label: umbrella	Pred label: umbrella
# IMG_ID: 8111	True label: umbrella	Pred label: butterfly
# IMG_ID: 8113	True label: umbrella	Pred label: umbrella
# IMG_ID: 8115	True label: umbrella	Pred label: lamp
# IMG_ID: 8117	True label: umbrella	Pred label: umbrella
# IMG_ID: 8119	True label: umbrella	Pred label: umbrella
# IMG_ID: 8121	True label: umbrella	Pred label: umbrella
# IMG_ID: 8123	True label: umbrella	Pred label: butterfly
# IMG_ID: 8125	True label: umbrella	Pred label: Faces
# IMG_ID: 8127	True label: umbrella	Pred label: umbrella
# IMG_ID: 8129	True label: umbrella	Pred label: umbrella
# IMG_ID: 8131	True label: umbrella	Pred label: umbrella
# IMG_ID: 8133	True label: umbrella	Pred label: umbrella
# IMG_ID: 8135	True label: umbrella	Pred label: umbrella
# IMG_ID: 8137	True label: umbrella	Pred label: umbrella
# IMG_ID: 8139	True label: umbrella	Pred label: umbrella
# IMG_ID: 8141	True label: umbrella	Pred label: umbrella
# IMG_ID: 8143	True label: umbrella	Pred label: umbrella
# IMG_ID: 8145	True label: umbrella	Pred label: umbrella
# IMG_ID: 8147	True label: umbrella	Pred label: pagoda
# IMG_ID: 8149	True label: umbrella	Pred label: umbrella
# IMG_ID: 8151	True label: umbrella	Pred label: pagoda
# IMG_ID: 8153	True label: watch	Pred label: watch
# IMG_ID: 8155	True label: watch	Pred label: headphone
# IMG_ID: 8157	True label: watch	Pred label: watch
# IMG_ID: 8159	True label: watch	Pred label: stapler
# IMG_ID: 8161	True label: watch	Pred label: watch
# IMG_ID: 8163	True label: watch	Pred label: watch
# IMG_ID: 8165	True label: watch	Pred label: watch
# IMG_ID: 8167	True label: watch	Pred label: watch
# IMG_ID: 8169	True label: watch	Pred label: watch
# IMG_ID: 8171	True label: watch	Pred label: watch
# IMG_ID: 8173	True label: watch	Pred label: watch
# IMG_ID: 8175	True label: watch	Pred label: watch
# IMG_ID: 8177	True label: watch	Pred label: watch
# IMG_ID: 8179	True label: watch	Pred label: watch
# IMG_ID: 8181	True label: watch	Pred label: watch
# IMG_ID: 8183	True label: watch	Pred label: watch
# IMG_ID: 8185	True label: watch	Pred label: watch
# IMG_ID: 8187	True label: watch	Pred label: watch
# IMG_ID: 8189	True label: watch	Pred label: watch
# IMG_ID: 8191	True label: watch	Pred label: watch
# IMG_ID: 8193	True label: watch	Pred label: watch
# IMG_ID: 8195	True label: watch	Pred label: watch
# IMG_ID: 8197	True label: watch	Pred label: watch
# IMG_ID: 8199	True label: watch	Pred label: watch
# IMG_ID: 8201	True label: watch	Pred label: watch
# IMG_ID: 8203	True label: watch	Pred label: watch
# IMG_ID: 8205	True label: watch	Pred label: watch
# IMG_ID: 8207	True label: watch	Pred label: watch
# IMG_ID: 8209	True label: watch	Pred label: watch
# IMG_ID: 8211	True label: watch	Pred label: watch
# IMG_ID: 8213	True label: watch	Pred label: watch
# IMG_ID: 8215	True label: watch	Pred label: watch
# IMG_ID: 8217	True label: watch	Pred label: watch
# IMG_ID: 8219	True label: watch	Pred label: watch
# IMG_ID: 8221	True label: watch	Pred label: wrench
# IMG_ID: 8223	True label: watch	Pred label: watch
# IMG_ID: 8225	True label: watch	Pred label: watch
# IMG_ID: 8227	True label: watch	Pred label: watch
# IMG_ID: 8229	True label: watch	Pred label: watch
# IMG_ID: 8231	True label: watch	Pred label: watch
# IMG_ID: 8233	True label: watch	Pred label: watch
# IMG_ID: 8235	True label: watch	Pred label: watch
# IMG_ID: 8237	True label: watch	Pred label: watch
# IMG_ID: 8239	True label: watch	Pred label: watch
# IMG_ID: 8241	True label: watch	Pred label: watch
# IMG_ID: 8243	True label: watch	Pred label: watch
# IMG_ID: 8245	True label: watch	Pred label: beaver
# IMG_ID: 8247	True label: watch	Pred label: watch
# IMG_ID: 8249	True label: watch	Pred label: watch
# IMG_ID: 8251	True label: watch	Pred label: watch
# IMG_ID: 8253	True label: watch	Pred label: watch
# IMG_ID: 8255	True label: watch	Pred label: watch
# IMG_ID: 8257	True label: watch	Pred label: watch
# IMG_ID: 8259	True label: watch	Pred label: watch
# IMG_ID: 8261	True label: watch	Pred label: butterfly
# IMG_ID: 8263	True label: watch	Pred label: electric_guitar
# IMG_ID: 8265	True label: watch	Pred label: watch
# IMG_ID: 8267	True label: watch	Pred label: watch
# IMG_ID: 8269	True label: watch	Pred label: watch
# IMG_ID: 8271	True label: watch	Pred label: watch
# IMG_ID: 8273	True label: watch	Pred label: watch
# IMG_ID: 8275	True label: watch	Pred label: watch
# IMG_ID: 8277	True label: watch	Pred label: watch
# IMG_ID: 8279	True label: watch	Pred label: watch
# IMG_ID: 8281	True label: watch	Pred label: watch
# IMG_ID: 8283	True label: watch	Pred label: watch
# IMG_ID: 8285	True label: watch	Pred label: watch
# IMG_ID: 8287	True label: watch	Pred label: watch
# IMG_ID: 8289	True label: watch	Pred label: watch
# IMG_ID: 8291	True label: watch	Pred label: watch
# IMG_ID: 8293	True label: watch	Pred label: watch
# IMG_ID: 8295	True label: watch	Pred label: watch
# IMG_ID: 8297	True label: watch	Pred label: watch
# IMG_ID: 8299	True label: watch	Pred label: watch
# IMG_ID: 8301	True label: watch	Pred label: watch
# IMG_ID: 8303	True label: watch	Pred label: watch
# IMG_ID: 8305	True label: watch	Pred label: watch
# IMG_ID: 8307	True label: watch	Pred label: watch
# IMG_ID: 8309	True label: watch	Pred label: watch
# IMG_ID: 8311	True label: watch	Pred label: watch
# IMG_ID: 8313	True label: watch	Pred label: watch
# IMG_ID: 8315	True label: watch	Pred label: watch
# IMG_ID: 8317	True label: watch	Pred label: watch
# IMG_ID: 8319	True label: watch	Pred label: watch
# IMG_ID: 8321	True label: watch	Pred label: watch
# IMG_ID: 8323	True label: watch	Pred label: watch
# IMG_ID: 8325	True label: watch	Pred label: watch
# IMG_ID: 8327	True label: watch	Pred label: watch
# IMG_ID: 8329	True label: watch	Pred label: watch
# IMG_ID: 8331	True label: watch	Pred label: watch
# IMG_ID: 8333	True label: watch	Pred label: watch
# IMG_ID: 8335	True label: watch	Pred label: watch
# IMG_ID: 8337	True label: watch	Pred label: watch
# IMG_ID: 8339	True label: watch	Pred label: watch
# IMG_ID: 8341	True label: watch	Pred label: watch
# IMG_ID: 8343	True label: watch	Pred label: watch
# IMG_ID: 8345	True label: watch	Pred label: menorah
# IMG_ID: 8347	True label: watch	Pred label: watch
# IMG_ID: 8349	True label: watch	Pred label: watch
# IMG_ID: 8351	True label: watch	Pred label: watch
# IMG_ID: 8353	True label: watch	Pred label: watch
# IMG_ID: 8355	True label: watch	Pred label: watch
# IMG_ID: 8357	True label: watch	Pred label: watch
# IMG_ID: 8359	True label: watch	Pred label: watch
# IMG_ID: 8361	True label: watch	Pred label: watch
# IMG_ID: 8363	True label: watch	Pred label: watch
# IMG_ID: 8365	True label: watch	Pred label: watch
# IMG_ID: 8367	True label: watch	Pred label: gramophone
# IMG_ID: 8369	True label: watch	Pred label: watch
# IMG_ID: 8371	True label: watch	Pred label: watch
# IMG_ID: 8373	True label: watch	Pred label: watch
# IMG_ID: 8375	True label: watch	Pred label: watch
# IMG_ID: 8377	True label: watch	Pred label: watch
# IMG_ID: 8379	True label: watch	Pred label: watch
# IMG_ID: 8381	True label: watch	Pred label: watch
# IMG_ID: 8383	True label: watch	Pred label: anchor
# IMG_ID: 8385	True label: watch	Pred label: watch
# IMG_ID: 8387	True label: watch	Pred label: watch
# IMG_ID: 8389	True label: watch	Pred label: watch
# IMG_ID: 8391	True label: watch	Pred label: watch
# IMG_ID: 8393	True label: water_lilly	Pred label: lotus
# IMG_ID: 8395	True label: water_lilly	Pred label: bonsai
# IMG_ID: 8397	True label: water_lilly	Pred label: sunflower
# IMG_ID: 8399	True label: water_lilly	Pred label: water_lilly
# IMG_ID: 8401	True label: water_lilly	Pred label: lotus
# IMG_ID: 8403	True label: water_lilly	Pred label: water_lilly
# IMG_ID: 8405	True label: water_lilly	Pred label: water_lilly
# IMG_ID: 8407	True label: water_lilly	Pred label: sunflower
# IMG_ID: 8409	True label: water_lilly	Pred label: lotus
# IMG_ID: 8411	True label: water_lilly	Pred label: lotus
# IMG_ID: 8413	True label: water_lilly	Pred label: lotus
# IMG_ID: 8415	True label: water_lilly	Pred label: brain
# IMG_ID: 8417	True label: water_lilly	Pred label: sunflower
# IMG_ID: 8419	True label: water_lilly	Pred label: lotus
# IMG_ID: 8421	True label: water_lilly	Pred label: water_lilly
# IMG_ID: 8423	True label: water_lilly	Pred label: water_lilly
# IMG_ID: 8425	True label: water_lilly	Pred label: lotus
# IMG_ID: 8427	True label: water_lilly	Pred label: bass
# IMG_ID: 8429	True label: wheelchair	Pred label: Motorbikes
# IMG_ID: 8431	True label: wheelchair	Pred label: chair
# IMG_ID: 8433	True label: wheelchair	Pred label: wheelchair
# IMG_ID: 8435	True label: wheelchair	Pred label: wheelchair
# IMG_ID: 8437	True label: wheelchair	Pred label: wheelchair
# IMG_ID: 8439	True label: wheelchair	Pred label: chair
# IMG_ID: 8441	True label: wheelchair	Pred label: wheelchair
# IMG_ID: 8443	True label: wheelchair	Pred label: wheelchair
# IMG_ID: 8445	True label: wheelchair	Pred label: helicopter
# IMG_ID: 8447	True label: wheelchair	Pred label: wheelchair
# IMG_ID: 8449	True label: wheelchair	Pred label: wheelchair
# IMG_ID: 8451	True label: wheelchair	Pred label: wheelchair
# IMG_ID: 8453	True label: wheelchair	Pred label: wheelchair
# IMG_ID: 8455	True label: wheelchair	Pred label: wheelchair
# IMG_ID: 8457	True label: wheelchair	Pred label: wheelchair
# IMG_ID: 8459	True label: wheelchair	Pred label: scissors
# IMG_ID: 8461	True label: wheelchair	Pred label: wheelchair
# IMG_ID: 8463	True label: wheelchair	Pred label: wheelchair
# IMG_ID: 8465	True label: wheelchair	Pred label: wheelchair
# IMG_ID: 8467	True label: wheelchair	Pred label: wheelchair
# IMG_ID: 8469	True label: wheelchair	Pred label: wheelchair
# IMG_ID: 8471	True label: wheelchair	Pred label: wheelchair
# IMG_ID: 8473	True label: wheelchair	Pred label: wheelchair
# IMG_ID: 8475	True label: wheelchair	Pred label: helicopter
# IMG_ID: 8477	True label: wheelchair	Pred label: helicopter
# IMG_ID: 8479	True label: wheelchair	Pred label: helicopter
# IMG_ID: 8481	True label: wheelchair	Pred label: wheelchair
# IMG_ID: 8483	True label: wheelchair	Pred label: wheelchair
# IMG_ID: 8485	True label: wheelchair	Pred label: scissors
# IMG_ID: 8487	True label: wheelchair	Pred label: wheelchair
# IMG_ID: 8489	True label: wild_cat	Pred label: Leopards
# IMG_ID: 8491	True label: wild_cat	Pred label: wild_cat
# IMG_ID: 8493	True label: wild_cat	Pred label: Leopards
# IMG_ID: 8495	True label: wild_cat	Pred label: wild_cat
# IMG_ID: 8497	True label: wild_cat	Pred label: wild_cat
# IMG_ID: 8499	True label: wild_cat	Pred label: wild_cat
# IMG_ID: 8501	True label: wild_cat	Pred label: wild_cat
# IMG_ID: 8503	True label: wild_cat	Pred label: wild_cat
# IMG_ID: 8505	True label: wild_cat	Pred label: wild_cat
# IMG_ID: 8507	True label: wild_cat	Pred label: wild_cat
# IMG_ID: 8509	True label: wild_cat	Pred label: wild_cat
# IMG_ID: 8511	True label: wild_cat	Pred label: wild_cat
# IMG_ID: 8513	True label: wild_cat	Pred label: cougar_body
# IMG_ID: 8515	True label: wild_cat	Pred label: wild_cat
# IMG_ID: 8517	True label: wild_cat	Pred label: wild_cat
# IMG_ID: 8519	True label: wild_cat	Pred label: wild_cat
# IMG_ID: 8521	True label: wild_cat	Pred label: cougar_body
# IMG_ID: 8523	True label: windsor_chair	Pred label: windsor_chair
# IMG_ID: 8525	True label: windsor_chair	Pred label: chair
# IMG_ID: 8527	True label: windsor_chair	Pred label: windsor_chair
# IMG_ID: 8529	True label: windsor_chair	Pred label: windsor_chair
# IMG_ID: 8531	True label: windsor_chair	Pred label: chair
# IMG_ID: 8533	True label: windsor_chair	Pred label: windsor_chair
# IMG_ID: 8535	True label: windsor_chair	Pred label: chair
# IMG_ID: 8537	True label: windsor_chair	Pred label: windsor_chair
# IMG_ID: 8539	True label: windsor_chair	Pred label: chair
# IMG_ID: 8541	True label: windsor_chair	Pred label: chair
# IMG_ID: 8543	True label: windsor_chair	Pred label: windsor_chair
# IMG_ID: 8545	True label: windsor_chair	Pred label: chair
# IMG_ID: 8547	True label: windsor_chair	Pred label: windsor_chair
# IMG_ID: 8549	True label: windsor_chair	Pred label: windsor_chair
# IMG_ID: 8551	True label: windsor_chair	Pred label: windsor_chair
# IMG_ID: 8553	True label: windsor_chair	Pred label: chair
# IMG_ID: 8555	True label: windsor_chair	Pred label: windsor_chair
# IMG_ID: 8557	True label: windsor_chair	Pred label: chair
# IMG_ID: 8559	True label: windsor_chair	Pred label: chair
# IMG_ID: 8561	True label: windsor_chair	Pred label: windsor_chair
# IMG_ID: 8563	True label: windsor_chair	Pred label: chair
# IMG_ID: 8565	True label: windsor_chair	Pred label: windsor_chair
# IMG_ID: 8567	True label: windsor_chair	Pred label: chair
# IMG_ID: 8569	True label: windsor_chair	Pred label: windsor_chair
# IMG_ID: 8571	True label: windsor_chair	Pred label: windsor_chair
# IMG_ID: 8573	True label: windsor_chair	Pred label: windsor_chair
# IMG_ID: 8575	True label: windsor_chair	Pred label: windsor_chair
# IMG_ID: 8577	True label: windsor_chair	Pred label: chair
# IMG_ID: 8579	True label: wrench	Pred label: garfield
# IMG_ID: 8581	True label: wrench	Pred label: scissors
# IMG_ID: 8583	True label: wrench	Pred label: chandelier
# IMG_ID: 8585	True label: wrench	Pred label: wrench
# IMG_ID: 8587	True label: wrench	Pred label: wrench
# IMG_ID: 8589	True label: wrench	Pred label: minaret
# IMG_ID: 8591	True label: wrench	Pred label: wrench
# IMG_ID: 8593	True label: wrench	Pred label: helicopter
# IMG_ID: 8595	True label: wrench	Pred label: wrench
# IMG_ID: 8597	True label: wrench	Pred label: wrench
# IMG_ID: 8599	True label: wrench	Pred label: Faces
# IMG_ID: 8601	True label: wrench	Pred label: wrench
# IMG_ID: 8603	True label: wrench	Pred label: wrench
# IMG_ID: 8605	True label: wrench	Pred label: scissors
# IMG_ID: 8607	True label: wrench	Pred label: wrench
# IMG_ID: 8609	True label: wrench	Pred label: scissors
# IMG_ID: 8611	True label: wrench	Pred label: mandolin
# IMG_ID: 8613	True label: wrench	Pred label: stop_sign
# IMG_ID: 8615	True label: wrench	Pred label: wrench
# IMG_ID: 8617	True label: yin_yang	Pred label: yin_yang
# IMG_ID: 8619	True label: yin_yang	Pred label: yin_yang
# IMG_ID: 8621	True label: yin_yang	Pred label: yin_yang
# IMG_ID: 8623	True label: yin_yang	Pred label: soccer_ball
# IMG_ID: 8625	True label: yin_yang	Pred label: gramophone
# IMG_ID: 8627	True label: yin_yang	Pred label: soccer_ball
# IMG_ID: 8629	True label: yin_yang	Pred label: soccer_ball
# IMG_ID: 8631	True label: yin_yang	Pred label: yin_yang
# IMG_ID: 8633	True label: yin_yang	Pred label: watch
# IMG_ID: 8635	True label: yin_yang	Pred label: yin_yang
# IMG_ID: 8637	True label: yin_yang	Pred label: yin_yang
# IMG_ID: 8639	True label: yin_yang	Pred label: watch
# IMG_ID: 8641	True label: yin_yang	Pred label: yin_yang
# IMG_ID: 8643	True label: yin_yang	Pred label: yin_yang
# IMG_ID: 8645	True label: yin_yang	Pred label: anchor
# IMG_ID: 8647	True label: yin_yang	Pred label: stapler
# IMG_ID: 8649	True label: yin_yang	Pred label: ceiling_fan
# IMG_ID: 8651	True label: yin_yang	Pred label: soccer_ball
# IMG_ID: 8653	True label: yin_yang	Pred label: yin_yang
# IMG_ID: 8655	True label: yin_yang	Pred label: yin_yang
# IMG_ID: 8657	True label: yin_yang	Pred label: dollar_bill
# IMG_ID: 8659	True label: yin_yang	Pred label: yin_yang
# IMG_ID: 8661	True label: yin_yang	Pred label: yin_yang
# IMG_ID: 8663	True label: yin_yang	Pred label: yin_yang
# IMG_ID: 8665	True label: yin_yang	Pred label: yin_yang
# IMG_ID: 8667	True label: yin_yang	Pred label: yin_yang
# IMG_ID: 8669	True label: yin_yang	Pred label: anchor
# IMG_ID: 8671	True label: yin_yang	Pred label: yin_yang
# IMG_ID: 8673	True label: yin_yang	Pred label: yin_yang
# IMG_ID: 8675	True label: yin_yang	Pred label: chandelier

# %%
from utils.perf_utils import PerLabelPerf
from utils.dataset_utils import initialize_dataset
all_labels = initialize_dataset().categories
perf_calc = PerLabelPerf(all_labels)

for tuple in output_labels:
    perf_calc.process_perf(y=tuple["test_label"], y_pred=tuple["predicted_label"])
# Out:
# Downloading dataset if not present.
# Files already downloaded and verified

# %%
from utils.query_input_processor import align_print

print("Per-label Precision, Recall, F1 Scores for", out_statement + ":\n")
max_label_len = max([len(label) for label in all_labels])
decimals = 4

for label in all_labels:
    precision = str(round(perf_calc.get_precision(label), decimals))
    recall = str(round(perf_calc.get_recall(label), decimals))
    f1_score = str(round(perf_calc.get_f1_score(label), decimals))
    print(f"Label: {align_print(label, max_label_len)}\tPrecision: {align_print(precision, decimals+2)}\tRecall: {align_print(recall, decimals+2)} \t F1 score:{align_print(f1_score, decimals+2)}\t")

print("\n\nOverall accuracy for " + out_statement + f": {perf_calc.get_overall_accuracy() * 100}%")
# Out:
# Per-label Precision, Recall, F1 Scores for Decision Tree Classifier with Mode = gini, Min-Sample-Size= 25, and Max-Depth = 0:
#
# Label: Faces          	Precision: 0.7802	Recall: 0.9816 	 F1 score:0.8694
# Label: Faces_easy     	Precision: 0.9954	Recall: 0.9862 	 F1 score:0.9908
# Label: Leopards       	Precision: 0.9057	Recall: 0.96   	 F1 score:0.932
# Label: Motorbikes     	Precision: 0.9872	Recall: 0.9699 	 F1 score:0.9785
# Label: accordion      	Precision: 0.9259	Recall: 0.9259 	 F1 score:0.9259
# Label: airplanes      	Precision: 0.9632	Recall: 0.9825 	 F1 score:0.9728
# Label: anchor         	Precision: 0.0526	Recall: 0.0476 	 F1 score:0.05
# Label: ant            	Precision: 0.8333	Recall: 0.7143 	 F1 score:0.7692
# Label: barrel         	Precision: 0.9524	Recall: 0.8333 	 F1 score:0.8889
# Label: bass           	Precision: 0.4   	Recall: 0.5185 	 F1 score:0.4516
# Label: beaver         	Precision: 0.3415	Recall: 0.6087 	 F1 score:0.4375
# Label: binocular      	Precision: 0.9412	Recall: 1.0    	 F1 score:0.9697
# Label: bonsai         	Precision: 0.7397	Recall: 0.8438 	 F1 score:0.7883
# Label: brain          	Precision: 0.6383	Recall: 0.6122 	 F1 score:0.625
# Label: brontosaurus   	Precision: 0.2857	Recall: 0.2727 	 F1 score:0.2791
# Label: buddha         	Precision: 0.7353	Recall: 0.5952 	 F1 score:0.6579
# Label: butterfly      	Precision: 0.4107	Recall: 0.5    	 F1 score:0.451
# Label: camera         	Precision: 0.92  	Recall: 0.92   	 F1 score:0.92
# Label: cannon         	Precision: 0.6957	Recall: 0.7619 	 F1 score:0.7273
# Label: car_side       	Precision: 1.0   	Recall: 0.9194 	 F1 score:0.958
# Label: ceiling_fan    	Precision: 0.6471	Recall: 0.4783 	 F1 score:0.55
# Label: cellphone      	Precision: 0.9545	Recall: 0.7    	 F1 score:0.8077
# Label: chair          	Precision: 0.4681	Recall: 0.7097 	 F1 score:0.5641
# Label: chandelier     	Precision: 0.5   	Recall: 0.4717 	 F1 score:0.4854
# Label: cougar_body    	Precision: 0.72  	Recall: 0.75   	 F1 score:0.7347
# Label: cougar_face    	Precision: 0.6512	Recall: 0.8235 	 F1 score:0.7273
# Label: crab           	Precision: 0.6842	Recall: 0.7027 	 F1 score:0.6933
# Label: crayfish       	Precision: 0.5588	Recall: 0.5429 	 F1 score:0.5507
# Label: crocodile      	Precision: 0.95  	Recall: 0.76   	 F1 score:0.8444
# Label: crocodile_head 	Precision: 0.9167	Recall: 0.88   	 F1 score:0.898
# Label: cup            	Precision: 0.9545	Recall: 0.7241 	 F1 score:0.8235
# Label: dalmatian      	Precision: 1.0   	Recall: 0.9697 	 F1 score:0.9846
# Label: dollar_bill    	Precision: 0.3617	Recall: 0.6538 	 F1 score:0.4658
# Label: dolphin        	Precision: 0.875 	Recall: 0.6364 	 F1 score:0.7368
# Label: dragonfly      	Precision: 0.6364	Recall: 0.6176 	 F1 score:0.6269
# Label: electric_guitar	Precision: 0.619 	Recall: 0.3514 	 F1 score:0.4483
# Label: elephant       	Precision: 0.92  	Recall: 0.7188 	 F1 score:0.807
# Label: emu            	Precision: 0.5556	Recall: 0.7407 	 F1 score:0.6349
# Label: euphonium      	Precision: 0.9231	Recall: 0.75   	 F1 score:0.8276
# Label: ewer           	Precision: 0.9318	Recall: 0.9762 	 F1 score:0.9535
# Label: ferry          	Precision: 0.825 	Recall: 0.9706 	 F1 score:0.8919
# Label: flamingo       	Precision: 0.8966	Recall: 0.7879 	 F1 score:0.8387
# Label: flamingo_head  	Precision: 1.0   	Recall: 0.7826 	 F1 score:0.878
# Label: garfield       	Precision: 0.25  	Recall: 0.1176 	 F1 score:0.16
# Label: gerenuk        	Precision: 0.8667	Recall: 0.7647 	 F1 score:0.8125
# Label: gramophone     	Precision: 0.2069	Recall: 0.24   	 F1 score:0.2222
# Label: grand_piano    	Precision: 1.0   	Recall: 0.74   	 F1 score:0.8506
# Label: hawksbill      	Precision: 0.96  	Recall: 0.96   	 F1 score:0.96
# Label: headphone      	Precision: 0.6471	Recall: 0.5238 	 F1 score:0.5789
# Label: hedgehog       	Precision: 0.9583	Recall: 0.8519 	 F1 score:0.902
# Label: helicopter     	Precision: 0.3276	Recall: 0.4318 	 F1 score:0.3725
# Label: ibis           	Precision: 0.7059	Recall: 0.9    	 F1 score:0.7912
# Label: inline_skate   	Precision: 0.45  	Recall: 0.6    	 F1 score:0.5143
# Label: joshua_tree    	Precision: 0.95  	Recall: 0.5938 	 F1 score:0.7308
# Label: kangaroo       	Precision: 0.9545	Recall: 0.9767 	 F1 score:0.9655
# Label: ketch          	Precision: 0.8136	Recall: 0.8421 	 F1 score:0.8276
# Label: lamp           	Precision: 0.7308	Recall: 0.6129 	 F1 score:0.6667
# Label: laptop         	Precision: 0.95  	Recall: 0.95   	 F1 score:0.95
# Label: llama          	Precision: 0.931 	Recall: 0.6923 	 F1 score:0.7941
# Label: lobster        	Precision: 0.5333	Recall: 0.381  	 F1 score:0.4444
# Label: lotus          	Precision: 0.5833	Recall: 0.4242 	 F1 score:0.4912
# Label: mandolin       	Precision: 0.359 	Recall: 0.6667 	 F1 score:0.4667
# Label: mayfly         	Precision: 0.5714	Recall: 0.6    	 F1 score:0.5854
# Label: menorah        	Precision: 0.5946	Recall: 0.5    	 F1 score:0.5432
# Label: metronome      	Precision: 0.5294	Recall: 0.5625 	 F1 score:0.5455
# Label: minaret        	Precision: 0.8387	Recall: 0.6842 	 F1 score:0.7536
# Label: nautilus       	Precision: 0.9615	Recall: 0.9259 	 F1 score:0.9434
# Label: octopus        	Precision: 0.3333	Recall: 0.2778 	 F1 score:0.303
# Label: okapi          	Precision: 0.8947	Recall: 0.8947 	 F1 score:0.8947
# Label: pagoda         	Precision: 0.2143	Recall: 0.125  	 F1 score:0.1579
# Label: panda          	Precision: 0.9333	Recall: 0.7368 	 F1 score:0.8235
# Label: pigeon         	Precision: 0.7   	Recall: 0.6364 	 F1 score:0.6667
# Label: pizza          	Precision: 1.0   	Recall: 0.8148 	 F1 score:0.898
# Label: platypus       	Precision: 1.0   	Recall: 0.7059 	 F1 score:0.8276
# Label: pyramid        	Precision: 0.1923	Recall: 0.1786 	 F1 score:0.1852
# Label: revolver       	Precision: 1.0   	Recall: 1.0    	 F1 score:1.0
# Label: rhino          	Precision: 0.7419	Recall: 0.7667 	 F1 score:0.7541
# Label: rooster        	Precision: 0.8   	Recall: 0.8333 	 F1 score:0.8163
# Label: saxophone      	Precision: 0.9091	Recall: 1.0    	 F1 score:0.9524
# Label: schooner       	Precision: 0.7308	Recall: 0.5938 	 F1 score:0.6552
# Label: scissors       	Precision: 0.375 	Recall: 0.4737 	 F1 score:0.4186
# Label: scorpion       	Precision: 0.8605	Recall: 0.881  	 F1 score:0.8706
# Label: sea_horse      	Precision: 0.7   	Recall: 0.4828 	 F1 score:0.5714
# Label: snoopy         	Precision: 0.3158	Recall: 0.3529 	 F1 score:0.3333
# Label: soccer_ball    	Precision: 0.7941	Recall: 0.8438 	 F1 score:0.8182
# Label: stapler        	Precision: 0.625 	Recall: 0.4348 	 F1 score:0.5128
# Label: starfish       	Precision: 0.9762	Recall: 0.9535 	 F1 score:0.9647
# Label: stegosaurus    	Precision: 0.7692	Recall: 0.6897 	 F1 score:0.7273
# Label: stop_sign      	Precision: 0.9677	Recall: 0.9375 	 F1 score:0.9524
# Label: strawberry     	Precision: 0.8889	Recall: 0.8889 	 F1 score:0.8889
# Label: sunflower      	Precision: 0.766 	Recall: 0.8571 	 F1 score:0.809
# Label: tick           	Precision: 1.0   	Recall: 1.0    	 F1 score:1.0
# Label: trilobite      	Precision: 0.8723	Recall: 0.9535 	 F1 score:0.9111
# Label: umbrella       	Precision: 0.9655	Recall: 0.7568 	 F1 score:0.8485
# Label: watch          	Precision: 0.8672	Recall: 0.925  	 F1 score:0.8952
# Label: water_lilly    	Precision: 0.2941	Recall: 0.2778 	 F1 score:0.2857
# Label: wheelchair     	Precision: 0.5385	Recall: 0.7    	 F1 score:0.6087
# Label: wild_cat       	Precision: 0.5652	Recall: 0.7647 	 F1 score:0.65
# Label: windsor_chair  	Precision: 0.8889	Recall: 0.5714 	 F1 score:0.6957
# Label: wrench         	Precision: 0.4091	Recall: 0.4737 	 F1 score:0.439
# Label: yin_yang       	Precision: 0.8947	Recall: 0.5667 	 F1 score:0.6939
#
#
# Overall accuracy for Decision Tree Classifier with Mode = gini, Min-Sample-Size= 25, and Max-Depth = 0: 79.25311203319502%
